# %% [markdown]
# # Load and analyze the data

# %%
# Imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os

# %% [markdown]
# ## Load data

# %%
base_path = Path.cwd().parent
file_path = os.path.join(base_path, 'output/final_recipes/recipes_dataset_final.csv')

# %%
df_recipes = pd.read_csv(file_path, index_col=0, sep='|')

# %%
df_recipes.head(3)
# Out:
#                  name                                           raw_text  \
# 0         Fruit Salad  1. Fruit Salad: 70 calories per portion, 4 por...
# 1      Vegan Omelette  5. Vegan Omelette: 300 calories per portion, 1...
# 2  Vegan French Toast  7. Vegan French Toast: 400 calories per portio...
#
#   cultural_restriction  calories     allergens recipeId  \
# 0                vegan      70.0  NotAllergens   food_0
# 1                vegan     300.0       legumes   food_4
# 2                vegan     400.0  NotAllergens   food_6
#
#                                          ingredients  \
# 0  ingredients:\n- 1 apple\n- 1 banana\n- 1 orang...
# 1  ingredients:\n- 1 cup chickpea flour\n- 1 cup ...
# 2  ingredients:\n- 4 slices of vegan bread\n- 1 c...
#
#                                         instructions  carbohydrates   fat  \
# 0  \n1. wash and cut all the fruits into bite-siz...          223.0   2.0
# 1  \n1. in a mixing bowl, whisk together the chic...          100.0  20.5
# ...

# %% [markdown]
# ## Analysis
#
# Exploratory data analysis from the recipe data.

# %% [markdown]
# #### Data types
#
# Check data types from the dataset.

# %%
df_recipes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7017 entries, 0 to 704
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   name                  7017 non-null   object
#  1   raw_text              7017 non-null   object
#  2   cultural_restriction  7017 non-null   object
#  3   calories              7017 non-null   float64
#  4   allergens             7017 non-null   object
#  5   recipeId              7017 non-null   object
#  6   ingredients           7017 non-null   object
#  7   instructions          7017 non-null   object
#  8   carbohydrates         7017 non-null   float64
#  9   fat                   7017 non-null   float64
#  10  fiber                 7017 non-null   float64
#  11  protein               7017 non-null   float64
#  12  taste                 7017 non-null   object
#  13  cooking_style         7017 non-null   object
#  14  meal_type             7017 non-null   object
# ...

# %% [markdown]
# #### Analyze numerical columns

# %%
df_numerical = df_recipes.select_dtypes(include=np.number)

# %%
sns.set_theme(style='whitegrid', palette='deep', font_scale=1.1, rc={"figure.figsize":[8,5]})

# %%
sns.displot(df_numerical['calories'], 
            kde=True, 
            bins=20)

# %%
sns.displot(df_numerical['carbohydrates'], 
            kde=True, 
            bins=20)

# %%
sns.displot(df_numerical['fat'], 
            kde=True, 
            bins=20)

# %%
sns.displot(df_numerical['fiber'], 
            kde=True, 
            bins=20)

# %%
sns.displot(df_numerical['protein'], 
            kde=True, 
            bins=20)

# %%
sns.displot(df_numerical['prep_time'], 
            kde=True, 
            bins=20)

# %%
sns.displot(df_numerical['price'], 
            kde=True, 
            bins=20)
